# %%
import statistics
import matplotlib.pyplot as plt
import numpy
from scipy.stats import norm
correctness = [.7111111111111111, 0.6444444444444445, 0.7, 0.5777777777777777, 0.6777777777777778]
sim_time  = [151.657999992, 182.05800008773804, 147.4090001583099, 156.69400000572205, 236.2590000629425]
#correctness = correctness.sort()

# %%
print(correctness)
# Out:
# [0.7111111111111111, 0.6444444444444445, 0.7, 0.5777777777777777, 0.6777777777777778]

# %%
(statistics.mean(sim_time), statistics.stdev(sim_time) )
# Out:
# (174.8156000613425, 36.89014878558819)

# %%
(statistics.mean(correctness), statistics.stdev(correctness))
# Out:
# (0.6622222222222223, 0.053633415049543)
